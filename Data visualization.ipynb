# %%
import pandas as pd

# %%
df = pd.read_csv(open('runs_clears.csv'))

# %%
df[df.noise_level == 1]
# Out:
#       Unnamed: 0 method  parameter  total_features  noise_level  noisy_score  \
# 9              9    omp          1               3          1.0     0.783062
# 10            10    omp          2               3          1.0     0.818817
# 11            11    omp          3               3          1.0     0.818902
# 24            24    omp          1               4          1.0     0.771209
# 25            25    omp          2               4          1.0     0.816470
# ...          ...    ...        ...             ...          ...          ...
# 1027        1027    omp          5              33          1.0     0.809169
# 1028        1028    omp          6              33          1.0     0.809423
# 1029        1029    omp          7              33          1.0     0.809531
# 1030        1030    omp          8              33          1.0     0.809538
# 1031        1031    omp          9              33          1.0     0.809538
#
# ...
